# %% [markdown]
# <a href="https://colab.research.google.com/github/jk21bst/SimilarthingUsingFaissandstreamlit/blob/main/SimilarthingappUsingFaissstreamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 31.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 62.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.6 MB/s eta 0:00:00
# ...

# %%
# !pip install faiss-cpu
# !pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 46.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.7/224.7 kB 3.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
import streamlit as st

# %%
st.set_page_config(page_title="Educate Kids", page_icon=":robot:")
st.header=("Hey ask me anything I will tell you similar things")

# %%
import pandas as pd
data = pd.read_excel('/content/Dummy.xlsx')
print(data)
# Out:
#        Words    category
# 0        Cat      Animal
# 1        Dog      Animal
# 2   Elephant      Animal
# 3        Owl        Bird
# 4        Man       Human
# 5      Woman       Human
# 6       Girl       Human
# 7        Boy       Human
# 8      Truck  Automobile
# 9       Bike  Automobile
# 10   Sparrow        Bird
# 11      Crow        Bird
# 12    Banana       Fruit
# 13     Apple       Fruit
# 14     Dates       Fruit
# 15      Kiwi       Fruit
# 16    Orange       Fruit

# %%
df= pd.DataFrame(data,columns =['Words', 'category'])
print(df)
# Out:
#        Words    category
# 0        Cat      Animal
# 1        Dog      Animal
# 2   Elephant      Animal
# 3        Owl        Bird
# 4        Man       Human
# 5      Woman       Human
# 6       Girl       Human
# 7        Boy       Human
# 8      Truck  Automobile
# 9       Bike  Automobile
# 10   Sparrow        Bird
# 11      Crow        Bird
# 12    Banana       Fruit
# 13     Apple       Fruit
# 14     Dates       Fruit
# 15      Kiwi       Fruit
# 16    Orange       Fruit

# %%
from sentence_transformers import SentenceTransformer
text= df['Words']
encoder= SentenceTransformer("paraphrase-mpnet-base-v2")
vectors= encoder.encode(text)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/594 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
print(vectors)
# Out:
# [[-0.09844344  0.2795658  -0.03168973 ...  0.15806578  0.0752565
#   -0.13324963]
#  [-0.08864512  0.14512959 -0.05070074 ...  0.10075674  0.1177192
#   -0.09918139]
#  [ 0.04929429  0.25095817 -0.05038916 ...  0.08830488  0.09233829
#    0.02175453]
#  ...
#  [-0.10211415  0.13751256 -0.05710767 ... -0.01081211  0.12233166
#   -0.05202256]
#  [-0.07871318 -0.37134552  0.00444045 ... -0.02846699  0.08287781
#   -0.03705121]
#  [-0.06024797  0.12426224  0.03042831 ...  0.03778614 -0.00549669
#   -0.03999333]]

# %%
def get_text():
  input_text =st.text_input("You: ",key=input)
  return input_text

# %%
user_input=get_text()
submit=st.button('Find similar things')
if submit:
  st.text(merge['Words'].head(2))

# %%
import faiss
vector_dimension = vectors.shape[1]
index= faiss.IndexFlatL2(vector_dimension)
faiss.normalize_L2(vectors)
index.add(vectors)

# %%
import numpy as np
search_text = user_input
search_vector = encoder.encode(search_text)
_vector= np.array([search_vector])
faiss.normalize_L2(_vector)

# %%
k=index.ntotal
distances, ann =index.search(_vector, k=k)

# %%
results = pd.DataFrame({'distances' : distances[0],'ann': ann[0]})

# %%
print(results)
# Out:
#     distances  ann
# 0    1.127000   12
# 1    1.484005   15
# 2    1.506550   16
# 3    1.573383   10
# 4    1.687385    8
# 5    1.707251   13
# 6    1.708889   11
# 7    1.807442    7
# 8    1.815907   14
# 9    1.819007    2
# 10   1.822095    6
# 11   1.832132    5
# 12   1.868601    4
# 13   1.883792    1
# 14   1.884305    9
# 15   1.919472    3
# 16   1.994717    0

# %%
# join by: df1.ann == data.index
merge = pd.merge(results,df,left_on='ann',right_index=True)
print(merge)
# Out:
#     distances  ann     Words    category
# 0    1.127000   12    Banana       Fruit
# 1    1.484005   15      Kiwi       Fruit
# 2    1.506550   16    Orange       Fruit
# 3    1.573383   10   Sparrow        Bird
# 4    1.687385    8     Truck  Automobile
# 5    1.707251   13     Apple       Fruit
# 6    1.708889   11      Crow        Bird
# 7    1.807442    7       Boy       Human
# 8    1.815907   14     Dates       Fruit
# 9    1.819007    2  Elephant      Animal
# 10   1.822095    6      Girl       Human
# 11   1.832132    5     Woman       Human
# 12   1.868601    4       Man       Human
# 13   1.883792    1       Dog      Animal
# 14   1.884305    9      Bike  Automobile
# 15   1.919472    3       Owl        Bird
# 16   1.994717    0       Cat      Animal

# %%
# prompt: merge = pd.merge(results,df,left_on='ann',right_index=True)
# print(merge)
# I want to print frist two from merge and also only specific column value like There are four columns anamed distances ann word category
# I want to print only words which are first two not other column datas

print(merge['Words'].head(2))
# Out:
# 0    Banana
# 1      Kiwi
# Name: Words, dtype: object

# %%
# !wget -q -o - ipv4.icanhazip.com

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# added 22 packages from 22 contributors and audited 22 packages in 1.364s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 1 moderate severity vulnerability
#   run `npm audit fix` to fix them, or `npm audit` for details

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 2.573s
# your url is: https://long-lines-suffer.loca.lt
